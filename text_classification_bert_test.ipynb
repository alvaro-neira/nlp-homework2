# %%
# !pip install datasets transformers
# Out:
# ...
#      |████████████████████████████████| 306 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 3.4 MB 49.6 MB/s
# ...
#      |████████████████████████████████| 132 kB 69.0 MB/s
# ...
#      |████████████████████████████████| 61 kB 540 kB/s
# ...
#      |████████████████████████████████| 243 kB 57.9 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 50.0 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 56.6 MB/s
# ...
#      |████████████████████████████████| 895 kB 50.3 MB/s
# ...
#      |████████████████████████████████| 596 kB 45.4 MB/s
# ...
#      |████████████████████████████████| 192 kB 46.6 MB/s
# ...
#      |████████████████████████████████| 271 kB 42.3 MB/s
# ...
#      |████████████████████████████████| 160 kB 43.3 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
import transformers
import datasets
from datasets import load_dataset
import json
import csv
import pandas as pd
from sklearn.model_selection import train_test_split
print(transformers.__version__)
# Out:
# 4.15.0

# %%
# %cd /content
# !rm -rf nlp-homework2
# !git clone https://github.com/alvaro-neira/nlp-homework2.git
# Out:
# /content
# Cloning into 'nlp-homework2'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 74 (delta 40), reused 46 (delta 15), pack-reused 0
# Unpacking objects: 100% (74/74), done.

# %%
# !wget https://raw.githubusercontent.com/alvaro-neira/nlp-homework2/main/tiposmensajes.csv -O /content/tiposmensajes.csv
messages = pd.read_csv('/content/tiposmensajes.csv', sep=';')
messages.tail(59)
# Out:
# --2021-12-28 23:19:11--  https://raw.githubusercontent.com/alvaro-neira/nlp-homework2/main/tiposmensajes.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4213 (4.1K) [text/plain]
# Saving to: ‘/content/tiposmensajes.csv’
#
# /content/tiposmensa 100%[===================>]   4.11K  --.-KB/s    in 0s
#
# 2021-12-28 23:19:11 (51.7 MB/s) - ‘/content/tiposmensajes.csv’ saved [4213/4213]
#           Clase                                            Mensaje
# 1        saludo                                                 Hi
# 2        saludo                                        Buenos días
# 3        saludo                                      Buenas tardes
# 4        saludo                                         Como estas
# ...

# %%
(train_dataset,validation_dataset)=train_test_split(messages, test_size=0.2)

# %%
validation_dataset.tail()
# Out:
#           Clase                                            Mensaje
# 12       nombre                                             Yo soy
# 23  información  ¿Chilexpress solicita el RUT del destinatario ...
# 54  información  ¿Cómo puedo abrir una cuenta empresa con Chile...
# 33  información  ¿Cuáles son los plazos de entrega asociados a ...
# 1        saludo                                                 Hi

# %%
validation_dataset.to_csv('validation_dataset.csv',sep=';')

# %%
task = "nocola"
model_checkpoint = "dccuchile/bert-base-spanish-wwm-uncased"
batch_size = 16

# %%
dataset = load_dataset('/content/nlp-homework2/data_set_tarea2.py')
# Out:
# Using custom data configuration default
# Reusing dataset data_set_tarea2 (/root/.cache/huggingface/datasets/data_set_tarea2/default/0.0.0/d4c427397eef8aaee9c0f470a614772fa68820e0c60cce8f4fe8a461265f3624)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Clase', 'Mensaje'],
#         num_rows: 49
#     })
#     test: Dataset({
#         features: ['Clase', 'Mensaje'],
#         num_rows: 13
#     })
# })
